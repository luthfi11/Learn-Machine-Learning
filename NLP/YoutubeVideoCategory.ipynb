# %%
# !wget --no-check-certificate \
https://raw.githubusercontent.com/luthfi11/Learn-Machine-Learning/master/Youtube%20Video%20Dataset.csv -O /tmp/dataset.csv
# Out:
# --2020-08-26 11:13:12--  https://raw.githubusercontent.com/luthfi11/Learn-Machine-Learning/master/Youtube%20Video%20Dataset.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15401104 (15M) [text/plain]
# Saving to: ‘/tmp/dataset.csv’
#
# /tmp/dataset.csv    100%[===================>]  14.69M  32.2MB/s    in 0.5s
#
# 2020-08-26 11:13:14 (32.2 MB/s) - ‘/tmp/dataset.csv’ saved [15401104/15401104]

# %%
import pandas as pd

dataset = pd.read_csv("/tmp/dataset.csv")
dataset
# Out:
#                                                    Title  ...                                        Description
# 0      Madagascar Street Food!!! Super RARE Malagasy ...  ...  🎥GIANT ALIEN SNAIL IN JAPAN! » https://youtu.b...
# 1                42 Foods You Need To Eat Before You Die  ...  This is the ultimate must-try food bucket list...
# 2                    Gordon Ramsay’s Top 5 Indian Dishes  ...  We found 5 of the best and most interesting In...
# 3            How To Use Chopsticks - In About A Minute 🍜  ...  You're most likely sitting in a restaurant wit...
# 4                           Trying Indian Food 1st Time!  ...  HELP SUPPORT SINSTV!! Shop Our Sponsors!\nLast...
# ...                                                  ...  ...                                                ...
# 11206  art journal | shimmer sprays, stencils, collag...  ...  Step by step video on creating an art journal ...
# 11207                   Ar-Tea Collage * Mixed Media Art  ...  By: Ilene McInnes,\nMixed media Art and inspir...
# 11208  DIY Mixed Media Art Collage Greeting Cards / M...  ...  Make your own Mixed Media Greeting Cards\n\nHe...
# 11209  Art Collage Process DecoJournal using Rice Pap...  ...  Art Collage Process DecoJournal using Rice Pap...
# 11210  Journal Collage Process using Magazine Cut Out...  ...  Using magazine, scrapbook paper, recycled old ...
#
# [11211 rows x 4 columns]

# %%
category = pd.get_dummies(dataset.Category)

new_data = pd.concat([dataset[['Title']], category], axis=1)
new_data
# Out:
#                                                    Title  ...  travel blog
# 0      Madagascar Street Food!!! Super RARE Malagasy ...  ...            0
# 1                42 Foods You Need To Eat Before You Die  ...            0
# 2                    Gordon Ramsay’s Top 5 Indian Dishes  ...            0
# 3            How To Use Chopsticks - In About A Minute 🍜  ...            0
# 4                           Trying Indian Food 1st Time!  ...            0
# ...                                                  ...  ...          ...
# 11206  art journal | shimmer sprays, stencils, collag...  ...            0
# 11207                   Ar-Tea Collage * Mixed Media Art  ...            0
# 11208  DIY Mixed Media Art Collage Greeting Cards / M...  ...            0
# 11209  Art Collage Process DecoJournal using Rice Pap...  ...            0
# 11210  Journal Collage Process using Magazine Cut Out...  ...            0
#
# [11211 rows x 7 columns]

# %%
title = new_data['Title'].values
label = new_data.loc[:, new_data.columns != 'Title'].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(title, label, test_size=0.2)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words=1000, oov_token='x')

tokenizer.fit_on_texts(X_train) 
tokenizer.fit_on_texts(X_test)
 
sequences_train = tokenizer.texts_to_sequences(X_train)
sequences_test = tokenizer.texts_to_sequences(X_test)
 
padded_train = pad_sequences(sequences_train) 
padded_test = pad_sequences(sequences_test)

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(input_dim=1000, output_dim=16),
    tf.keras.layers.LSTM(64),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')
])

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
num_epochs = 30
history = model.fit(padded_train, y_train, epochs=num_epochs, 
                    validation_data=(padded_test, y_test), 
                    verbose=2)
# Out:
# Epoch 1/30
# 281/281 - 3s - loss: 0.8984 - accuracy: 0.6656 - val_loss: 0.3700 - val_accuracy: 0.8841
# Epoch 2/30
# 281/281 - 3s - loss: 0.2470 - accuracy: 0.9263 - val_loss: 0.2531 - val_accuracy: 0.9198
# Epoch 3/30
# 281/281 - 3s - loss: 0.1858 - accuracy: 0.9396 - val_loss: 0.2435 - val_accuracy: 0.9215
# Epoch 4/30
# 281/281 - 3s - loss: 0.1628 - accuracy: 0.9480 - val_loss: 0.2930 - val_accuracy: 0.9059
# Epoch 5/30
# 281/281 - 3s - loss: 0.1335 - accuracy: 0.9564 - val_loss: 0.2538 - val_accuracy: 0.9224
# Epoch 6/30
# 281/281 - 3s - loss: 0.1236 - accuracy: 0.9603 - val_loss: 0.2382 - val_accuracy: 0.9264
# Epoch 7/30
# 281/281 - 3s - loss: 0.1103 - accuracy: 0.9652 - val_loss: 0.2646 - val_accuracy: 0.9220
# Epoch 8/30
# 281/281 - 3s - loss: 0.1034 - accuracy: 0.9665 - val_loss: 0.2916 - val_accuracy: 0.9117
# Epoch 9/30
# 281/281 - 3s - loss: 0.0943 - accuracy: 0.9698 - val_loss: 0.2736 - val_accuracy: 0.9189
# Epoch 10/30
# 281/281 - 3s - loss: 0.0878 - accuracy: 0.9717 - val_loss: 0.2876 - val_accuracy: 0.9206
# Epoch 11/30
# 281/281 - 3s - loss: 0.0773 - accuracy: 0.9742 - val_loss: 0.3094 - val_accuracy: 0.9202
# Epoch 12/30
# 281/281 - 3s - loss: 0.0741 - accuracy: 0.9749 - val_loss: 0.3359 - val_accuracy: 0.9166
# Epoch 13/30
# 281/281 - 3s - loss: 0.0732 - accuracy: 0.9750 - val_loss: 0.3512 - val_accuracy: 0.9148
# Epoch 14/30
# 281/281 - 3s - loss: 0.0695 - accuracy: 0.9765 - val_loss: 0.3673 - val_accuracy: 0.9140
# Epoch 15/30
# 281/281 - 3s - loss: 0.0717 - accuracy: 0.9756 - val_loss: 0.3605 - val_accuracy: 0.9166
# Epoch 16/30
# 281/281 - 3s - loss: 0.0715 - accuracy: 0.9758 - val_loss: 0.3483 - val_accuracy: 0.9206
# Epoch 17/30
# 281/281 - 3s - loss: 0.0548 - accuracy: 0.9826 - val_loss: 0.3698 - val_accuracy: 0.9180
# Epoch 18/30
# 281/281 - 3s - loss: 0.0499 - accuracy: 0.9839 - val_loss: 0.3758 - val_accuracy: 0.9166
# Epoch 19/30
# 281/281 - 3s - loss: 0.0524 - accuracy: 0.9828 - val_loss: 0.4484 - val_accuracy: 0.9122
# Epoch 20/30
# 281/281 - 3s - loss: 0.0531 - accuracy: 0.9820 - val_loss: 0.4034 - val_accuracy: 0.9122
# Epoch 21/30
# 281/281 - 3s - loss: 0.0477 - accuracy: 0.9834 - val_loss: 0.4580 - val_accuracy: 0.9144
# Epoch 22/30
# 281/281 - 3s - loss: 0.0474 - accuracy: 0.9827 - val_loss: 0.4544 - val_accuracy: 0.9180
# Epoch 23/30
# 281/281 - 3s - loss: 0.0420 - accuracy: 0.9864 - val_loss: 0.4503 - val_accuracy: 0.9157
# Epoch 24/30
# 281/281 - 3s - loss: 0.0362 - accuracy: 0.9874 - val_loss: 0.4583 - val_accuracy: 0.9140
# Epoch 25/30
# 281/281 - 3s - loss: 0.0373 - accuracy: 0.9877 - val_loss: 0.4861 - val_accuracy: 0.9104
# Epoch 26/30
# 281/281 - 3s - loss: 0.0369 - accuracy: 0.9866 - val_loss: 0.4986 - val_accuracy: 0.9153
# Epoch 27/30
# 281/281 - 3s - loss: 0.0475 - accuracy: 0.9841 - val_loss: 0.4874 - val_accuracy: 0.9153
# Epoch 28/30
# 281/281 - 3s - loss: 0.0384 - accuracy: 0.9874 - val_loss: 0.5469 - val_accuracy: 0.9091
# Epoch 29/30
# 281/281 - 3s - loss: 0.0385 - accuracy: 0.9871 - val_loss: 0.5366 - val_accuracy: 0.9157
# Epoch 30/30
# 281/281 - 3s - loss: 0.0318 - accuracy: 0.9887 - val_loss: 0.5230 - val_accuracy: 0.9148
